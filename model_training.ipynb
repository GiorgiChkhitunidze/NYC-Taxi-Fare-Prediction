# %%
import pandas as pd

from sklearn.linear_model import LinearRegression
import xgboost as xgb
import pickle

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import uniform, randint

# %% [markdown]
# ## Baseline model

# %%
df = pd.read_csv("Data/NYC_Taxi_Dataset.csv", index_col='key').dropna()
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# let's split data into train/valid/test sets before we continue preprocessing
# Since dataset is quite big we will take 2% of rows for validation and 2% for testing.
train_df, valid_df = train_test_split(df, test_size=0.04, shuffle=True, random_state=42)
valid_df, test_df = train_test_split(valid_df, test_size=0.5, shuffle=True, random_state=42)

# remove df to free up space
del df

# %%
X_train = train_df.drop(['fare_amount', 'pickup_datetime'], axis=1)
y_train = train_df['fare_amount']
X_test = test_df.drop(['fare_amount', 'pickup_datetime'], axis=1)
y_test = test_df['fare_amount']

# Scale the features
scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_train.index = y_train.index
X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)
X_test.index = y_test.index

# Create a linear regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Calculate the RMSE
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("Root Mean Squared Error (RMSE):", rmse, end='\n\n')
# Out:
# Root Mean Squared Error (RMSE): 9.576859470263193

# %% [markdown]
# <p style='color:red;'>So, for the initial model we only dropped missing values and used pickup/dropoff coordinates and passenger count as independent variables. We did not check validity of data, or outliers. Basically we did nothing. Therefore, performance is terible. P-values of all the variables except passenger_count are way more than 0.05 suggesting that there is not enough evedence to reject null hypothesis of no significant relationship. We will try to and hopefully improve this model.</p>

# %% [markdown]
# ## First Try To Improve

# %% [markdown]
# ## Data

# %% [markdown]
# <p style='color:red;'>For the following steps I will be using dataset cleaned in <b style='font-size:17px;color:yellow;'><i>clean_visualize_engineer.ipynb</i></b> notebook.</p>

# %% [markdown]
# <ul style='color:red;'><b style='font-size:17px;color:yellow;'>fare_amount:</b> amout of fare paid for taxi ride</ul>
# <ul style='color:red;'><b style='font-size:17px;color:yellow;'>[pickup_latitude, pickup_longitude]:</b> pickup location coordinates</ul>
# <ul style='color:red;'><b style='font-size:17px;color:yellow;'>[dropoff_latitude, dropoff_longitude]:</b> dropoff location coordinates</ul>
# <ul style='color:red;'><b style='font-size:17px;color:yellow;'>passenger_count:</b> number of passenger taxi took</ul>
# <ul style='color:red;'><b style='font-size:17px;color:yellow;'>pickup boroughs:</b> 5 pickup borough dummy columns</ul>
# <ul style='color:red;'><b style='font-size:17px;color:yellow;'>dropoff boroughs:</b> 5 dropoff borough dummy columns</ul>
# <ul style='color:red;'><b style='font-size:17px;color:yellow;'>distance_covered:</b> distance covered during a taxi ride</ul>
# <ul style='color:red;'><b style='font-size:17px;color:yellow;'>distance_to_airport:</b> distance from pickup/dropoff location to closest airport</ul>
# <ul style='color:red;'><b style='font-size:17px;color:yellow;'>year, month, week, day_of_month, day_of_week, hour, numeric_date:</b> time features describing taxi pickup prediod.</ul>
# <ul style='color:red;'><b style='font-size:17px;color:yellow;'>after_nov_2012:</b>Becasue fare jumped up in 2012, it is 0 if date was before Novemebr of 2012, and 1 if it was after November of 2012</ul>

# %%
train_df = pd.read_csv('Data/train_df.csv', index_col='key')
valid_df =pd.read_csv('Data/valid_df.csv', index_col='key')
test_df = pd.read_csv('Data/test_df.csv', index_col='key')

# %%
train_df.shape, valid_df.shape, test_df.shape
# Out:
# ((4603014, 26), (97756, 26), (97752, 26))

# %% [markdown]
# ## Linear Model

# %%
X_train = train_df.drop(['fare_amount'], axis=1)
y_train = train_df['fare_amount']
X_test = test_df.drop(['fare_amount'], axis=1)
y_test = test_df['fare_amount']

# Scale the features
scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_train.index = y_train.index
X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)
X_test.index = y_test.index

# Create a random forest regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Calculate the RMSE
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("Root Mean Squared Error (RMSE):", rmse, end='\n\n')
# Out:
# Root Mean Squared Error (RMSE): 5.157373169472006

# %% [markdown]
# ## XGBOOST

# %% [markdown]
# ### Conduct randomized search to fine tune model

# %%
# Get data
X_train = train_df.drop(['fare_amount'], axis=1)
y_train = train_df['fare_amount']

# Scale the features
scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_train.index = y_train.index

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_train.sample(100000, random_state=42), y_train.sample(100000, random_state=42), test_size=0.2, random_state=42)

# Define the parameter distributions for randomized search
param_dist = {
    "learning_rate": uniform(0.01, 0.1),
    "n_estimators": randint(100, 1000),
    "max_depth": randint(3, 8),
    "subsample": uniform(0.5, 0.5),
    "colsample_bytree": uniform(0.5, 0.5),
    "gamma": uniform(0, 1),
    "reg_alpha": uniform(0, 1),
    "reg_lambda": uniform(0, 1),
    "min_child_weight": randint(1, 10),
}

# Create the XGBoost regressor
xgb_model = xgb.XGBRegressor()

# Perform randomized search with cross-validation
random_search = RandomizedSearchCV(
    xgb_model, param_distributions=param_dist, n_iter=10, cv=5, scoring="neg_mean_squared_error", random_state=42
)
random_search.fit(X_train, y_train)

# Get the best hyperparameters and model
best_params = random_search.best_params_
best_model = random_search.best_estimator_

# Evaluate the model on the test set
y_pred = best_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5

# Print the best hyperparameters and evaluation metrics
print("Best Hyperparameters:", best_params)
print("Root Mean Squared Error:", rmse)
# Out:
# Best Hyperparameters: {'colsample_bytree': 0.8416317594127292, 'gamma': 0.6099966577826209, 'learning_rate': 0.09331949117361643, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 661, 'reg_alpha': 0.662522284353982, 'reg_lambda': 0.31171107608941095, 'subsample': 0.7600340105889054}
# Root Mean Squared Error: 2.8867515529670067

# %% [markdown]
# ### Train model

# %%
X_train = train_df.drop(['fare_amount'], axis=1)
y_train = train_df['fare_amount']
X_valid = valid_df.drop(['fare_amount'], axis=1)
y_valid = valid_df['fare_amount']
X_test = test_df.drop(['fare_amount'], axis=1)
y_test = test_df['fare_amount']

# Scale the features
scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_train.index = y_train.index
X_valid = pd.DataFrame(scaler.transform(X_valid), columns=X_valid.columns)
X_valid.index = y_valid.index
X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)
X_test.index = y_test.index

# %%
my_model = xgb.XGBRegressor(
    colsample_bytree=0.8416317594127292, 
    gamma=0.6099966577826209,
    learning_rate=0.09331949117361643,
    max_depth=5,
    min_child_weight=1,
    n_estimators=661,
    reg_alpha=0.662522284353982,
    reg_lambda=0.31171107608941095,
    subsample=0.7600340105889054
    )
my_model.fit(X_train, y_train, 
             eval_set=[(X_valid, y_valid)])
# Out:
# [0]	validation_0-rmse:12.99806
# [1]	validation_0-rmse:11.92012
# [2]	validation_0-rmse:10.95203
# [3]	validation_0-rmse:10.08369
# [4]	validation_0-rmse:9.30651
# [5]	validation_0-rmse:8.61670
# [6]	validation_0-rmse:8.00196
# [7]	validation_0-rmse:7.48041
# [8]	validation_0-rmse:6.99106
# [9]	validation_0-rmse:6.56226
# [10]	validation_0-rmse:6.18347
# [11]	validation_0-rmse:5.85470
# [12]	validation_0-rmse:5.56791
# [13]	validation_0-rmse:5.32529
# [14]	validation_0-rmse:5.11358
# [15]	validation_0-rmse:4.92179
# [16]	validation_0-rmse:4.76496
# [17]	validation_0-rmse:4.62067
# [18]	validation_0-rmse:4.50407
# [19]	validation_0-rmse:4.39667
# [20]	validation_0-rmse:4.30508
# [21]	validation_0-rmse:4.22932
# [22]	validation_0-rmse:4.16139
# [23]	validation_0-rmse:4.10330
# [24]	validation_0-rmse:4.05250
# [25]	validation_0-rmse:4.00735
# [26]	validation_0-rmse:3.96987
# [27]	validation_0-rmse:3.93743
# [28]	validation_0-rmse:3.91033
# [29]	validation_0-rmse:3.88604
# [30]	validation_0-rmse:3.86790
# [31]	validation_0-rmse:3.85221
# [32]	validation_0-rmse:3.83821
# [33]	validation_0-rmse:3.82463
# [34]	validation_0-rmse:3.81284
# [35]	validation_0-rmse:3.80141
# [36]	validation_0-rmse:3.79106
# [37]	validation_0-rmse:3.78243
# [38]	validation_0-rmse:3.77349
# [39]	validation_0-rmse:3.76519
# [40]	validation_0-rmse:3.75935
# [41]	validation_0-rmse:3.75185
# [42]	validation_0-rmse:3.74473
# [43]	validation_0-rmse:3.73945
# [44]	validation_0-rmse:3.73278
# [45]	validation_0-rmse:3.72769
# [46]	validation_0-rmse:3.72401
# [47]	validation_0-rmse:3.71905
# [48]	validation_0-rmse:3.71573
# [49]	validation_0-rmse:3.71129
# [50]	validation_0-rmse:3.70829
# [51]	validation_0-rmse:3.70445
# [52]	validation_0-rmse:3.70237
# [53]	validation_0-rmse:3.69850
# [54]	validation_0-rmse:3.69554
# [55]	validation_0-rmse:3.69320
# [56]	validation_0-rmse:3.69200
# [57]	validation_0-rmse:3.68853
# [58]	validation_0-rmse:3.68547
# [59]	validation_0-rmse:3.68362
# [60]	validation_0-rmse:3.68228
# [61]	validation_0-rmse:3.68078
# [62]	validation_0-rmse:3.67987
# [63]	validation_0-rmse:3.67747
# [64]	validation_0-rmse:3.67585
# [65]	validation_0-rmse:3.67249
# [66]	validation_0-rmse:3.67161
# [67]	validation_0-rmse:3.67086
# [68]	validation_0-rmse:3.66943
# [69]	validation_0-rmse:3.66744
# [70]	validation_0-rmse:3.66616
# [71]	validation_0-rmse:3.66532
# [72]	validation_0-rmse:3.66335
# [73]	validation_0-rmse:3.66212
# [74]	validation_0-rmse:3.65914
# [75]	validation_0-rmse:3.65765
# [76]	validation_0-rmse:3.65561
# [77]	validation_0-rmse:3.65395
# [78]	validation_0-rmse:3.65101
# [79]	validation_0-rmse:3.64925
# [80]	validation_0-rmse:3.64839
# [81]	validation_0-rmse:3.64774
# [82]	validation_0-rmse:3.64476
# [83]	validation_0-rmse:3.64427
# [84]	validation_0-rmse:3.64345
# [85]	validation_0-rmse:3.64230
# [86]	validation_0-rmse:3.64122
# [87]	validation_0-rmse:3.64030
# [88]	validation_0-rmse:3.63935
# [89]	validation_0-rmse:3.63865
# [90]	validation_0-rmse:3.63813
# [91]	validation_0-rmse:3.63701
# [92]	validation_0-rmse:3.63587
# [93]	validation_0-rmse:3.63490
# [94]	validation_0-rmse:3.63420
# [95]	validation_0-rmse:3.63296
# [96]	validation_0-rmse:3.63055
# [97]	validation_0-rmse:3.62866
# [98]	validation_0-rmse:3.62747
# [99]	validation_0-rmse:3.62677
# [100]	validation_0-rmse:3.62616
# [101]	validation_0-rmse:3.62574
# [102]	validation_0-rmse:3.62458
# [103]	validation_0-rmse:3.62416
# [104]	validation_0-rmse:3.62256
# [105]	validation_0-rmse:3.62165
# [106]	validation_0-rmse:3.62008
# [107]	validation_0-rmse:3.61989
# [108]	validation_0-rmse:3.61950
# [109]	validation_0-rmse:3.61871
# [110]	validation_0-rmse:3.61797
# [111]	validation_0-rmse:3.61553
# [112]	validation_0-rmse:3.61428
# [113]	validation_0-rmse:3.61292
# [114]	validation_0-rmse:3.61211
# [115]	validation_0-rmse:3.61095
# [116]	validation_0-rmse:3.60951
# [117]	validation_0-rmse:3.60882
# [118]	validation_0-rmse:3.60830
# [119]	validation_0-rmse:3.60671
# [120]	validation_0-rmse:3.60538
# [121]	validation_0-rmse:3.60514
# [122]	validation_0-rmse:3.60449
# [123]	validation_0-rmse:3.60358
# [124]	validation_0-rmse:3.60340
# [125]	validation_0-rmse:3.60315
# [126]	validation_0-rmse:3.60285
# [127]	validation_0-rmse:3.60213
# [128]	validation_0-rmse:3.60179
# [129]	validation_0-rmse:3.60110
# [130]	validation_0-rmse:3.59975
# [131]	validation_0-rmse:3.59892
# [132]	validation_0-rmse:3.59864
# [133]	validation_0-rmse:3.59814
# [134]	validation_0-rmse:3.59744
# [135]	validation_0-rmse:3.59524
# [136]	validation_0-rmse:3.59463
# [137]	validation_0-rmse:3.59379
# [138]	validation_0-rmse:3.59274
# [139]	validation_0-rmse:3.59221
# [140]	validation_0-rmse:3.59204
# [141]	validation_0-rmse:3.59178
# [142]	validation_0-rmse:3.59069
# [143]	validation_0-rmse:3.58979
# [144]	validation_0-rmse:3.58849
# [145]	validation_0-rmse:3.58719
# [146]	validation_0-rmse:3.58694
# [147]	validation_0-rmse:3.58657
# [148]	validation_0-rmse:3.58536
# [149]	validation_0-rmse:3.58524
# [150]	validation_0-rmse:3.58465
# [151]	validation_0-rmse:3.58385
# [152]	validation_0-rmse:3.58333
# [153]	validation_0-rmse:3.58247
# [154]	validation_0-rmse:3.58182
# [155]	validation_0-rmse:3.58163
# [156]	validation_0-rmse:3.58080
# [157]	validation_0-rmse:3.58063
# [158]	validation_0-rmse:3.57970
# [159]	validation_0-rmse:3.57883
# [160]	validation_0-rmse:3.57740
# [161]	validation_0-rmse:3.57665
# [162]	validation_0-rmse:3.57627
# [163]	validation_0-rmse:3.57610
# [164]	validation_0-rmse:3.57581
# [165]	validation_0-rmse:3.57529
# [166]	validation_0-rmse:3.57512
# [167]	validation_0-rmse:3.57350
# [168]	validation_0-rmse:3.57211
# [169]	validation_0-rmse:3.57183
# [170]	validation_0-rmse:3.57139
# [171]	validation_0-rmse:3.57048
# [172]	validation_0-rmse:3.57040
# [173]	validation_0-rmse:3.56953
# [174]	validation_0-rmse:3.56893
# [175]	validation_0-rmse:3.56812
# [176]	validation_0-rmse:3.56751
# [177]	validation_0-rmse:3.56571
# [178]	validation_0-rmse:3.56548
# [179]	validation_0-rmse:3.56464
# [180]	validation_0-rmse:3.56389
# [181]	validation_0-rmse:3.56368
# [182]	validation_0-rmse:3.56200
# [183]	validation_0-rmse:3.56095
# [184]	validation_0-rmse:3.56025
# [185]	validation_0-rmse:3.55952
# [186]	validation_0-rmse:3.55945
# [187]	validation_0-rmse:3.55864
# [188]	validation_0-rmse:3.55825
# [189]	validation_0-rmse:3.55740
# [190]	validation_0-rmse:3.55726
# [191]	validation_0-rmse:3.55724
# [192]	validation_0-rmse:3.55663
# [193]	validation_0-rmse:3.55586
# [194]	validation_0-rmse:3.55572
# [195]	validation_0-rmse:3.55545
# [196]	validation_0-rmse:3.55604
# [197]	validation_0-rmse:3.55587
# [198]	validation_0-rmse:3.55476
# [199]	validation_0-rmse:3.55440
# [200]	validation_0-rmse:3.55398
# [201]	validation_0-rmse:3.55378
# [202]	validation_0-rmse:3.55357
# [203]	validation_0-rmse:3.55287
# [204]	validation_0-rmse:3.55228
# [205]	validation_0-rmse:3.55214
# [206]	validation_0-rmse:3.55169
# [207]	validation_0-rmse:3.55123
# [208]	validation_0-rmse:3.55037
# [209]	validation_0-rmse:3.55047
# [210]	validation_0-rmse:3.54998
# [211]	validation_0-rmse:3.54961
# [212]	validation_0-rmse:3.54922
# [213]	validation_0-rmse:3.54926
# [214]	validation_0-rmse:3.54830
# [215]	validation_0-rmse:3.54817
# [216]	validation_0-rmse:3.54793
# [217]	validation_0-rmse:3.54766
# [218]	validation_0-rmse:3.54681
# [219]	validation_0-rmse:3.54666
# [220]	validation_0-rmse:3.54635
# [221]	validation_0-rmse:3.54577
# [222]	validation_0-rmse:3.54547
# [223]	validation_0-rmse:3.54484
# [224]	validation_0-rmse:3.54452
# [225]	validation_0-rmse:3.54408
# [226]	validation_0-rmse:3.54392
# [227]	validation_0-rmse:3.54407
# [228]	validation_0-rmse:3.54387
# [229]	validation_0-rmse:3.54259
# [230]	validation_0-rmse:3.54237
# [231]	validation_0-rmse:3.54219
# [232]	validation_0-rmse:3.54181
# [233]	validation_0-rmse:3.54157
# [234]	validation_0-rmse:3.54118
# [235]	validation_0-rmse:3.54095
# [236]	validation_0-rmse:3.54057
# [237]	validation_0-rmse:3.54045
# [238]	validation_0-rmse:3.53953
# [239]	validation_0-rmse:3.53979
# [240]	validation_0-rmse:3.53946
# [241]	validation_0-rmse:3.53933
# [242]	validation_0-rmse:3.53887
# [243]	validation_0-rmse:3.53899
# [244]	validation_0-rmse:3.53839
# [245]	validation_0-rmse:3.53808
# [246]	validation_0-rmse:3.53724
# [247]	validation_0-rmse:3.53629
# [248]	validation_0-rmse:3.53627
# [249]	validation_0-rmse:3.53596
# [250]	validation_0-rmse:3.53534
# [251]	validation_0-rmse:3.53544
# [252]	validation_0-rmse:3.53505
# [253]	validation_0-rmse:3.53491
# [254]	validation_0-rmse:3.53569
# [255]	validation_0-rmse:3.53527
# [256]	validation_0-rmse:3.53523
# [257]	validation_0-rmse:3.53477
# [258]	validation_0-rmse:3.53425
# [259]	validation_0-rmse:3.53400
# [260]	validation_0-rmse:3.53304
# [261]	validation_0-rmse:3.53241
# [262]	validation_0-rmse:3.53212
# [263]	validation_0-rmse:3.53220
# [264]	validation_0-rmse:3.53213
# [265]	validation_0-rmse:3.53208
# [266]	validation_0-rmse:3.53208
# [267]	validation_0-rmse:3.53200
# [268]	validation_0-rmse:3.53156
# [269]	validation_0-rmse:3.53141
# [270]	validation_0-rmse:3.53130
# [271]	validation_0-rmse:3.53109
# [272]	validation_0-rmse:3.53135
# [273]	validation_0-rmse:3.53118
# [274]	validation_0-rmse:3.53107
# [275]	validation_0-rmse:3.53095
# [276]	validation_0-rmse:3.53087
# [277]	validation_0-rmse:3.53012
# [278]	validation_0-rmse:3.52916
# [279]	validation_0-rmse:3.52851
# [280]	validation_0-rmse:3.52853
# [281]	validation_0-rmse:3.52804
# [282]	validation_0-rmse:3.52757
# [283]	validation_0-rmse:3.52726
# [284]	validation_0-rmse:3.52748
# [285]	validation_0-rmse:3.52740
# [286]	validation_0-rmse:3.52709
# [287]	validation_0-rmse:3.52717
# [288]	validation_0-rmse:3.52693
# [289]	validation_0-rmse:3.52644
# [290]	validation_0-rmse:3.52578
# [291]	validation_0-rmse:3.52607
# [292]	validation_0-rmse:3.52602
# [293]	validation_0-rmse:3.52595
# [294]	validation_0-rmse:3.52546
# [295]	validation_0-rmse:3.52452
# [296]	validation_0-rmse:3.52431
# [297]	validation_0-rmse:3.52446
# [298]	validation_0-rmse:3.52363
# [299]	validation_0-rmse:3.52343
# [300]	validation_0-rmse:3.52307
# [301]	validation_0-rmse:3.52294
# [302]	validation_0-rmse:3.52290
# [303]	validation_0-rmse:3.52325
# [304]	validation_0-rmse:3.52340
# [305]	validation_0-rmse:3.52332
# [306]	validation_0-rmse:3.52284
# [307]	validation_0-rmse:3.52277
# [308]	validation_0-rmse:3.52252
# [309]	validation_0-rmse:3.52239
# [310]	validation_0-rmse:3.52242
# [311]	validation_0-rmse:3.52208
# [312]	validation_0-rmse:3.52105
# [313]	validation_0-rmse:3.52054
# [314]	validation_0-rmse:3.52018
# [315]	validation_0-rmse:3.51901
# [316]	validation_0-rmse:3.51905
# [317]	validation_0-rmse:3.51866
# [318]	validation_0-rmse:3.51878
# [319]	validation_0-rmse:3.51859
# [320]	validation_0-rmse:3.51850
# [321]	validation_0-rmse:3.51825
# [322]	validation_0-rmse:3.51768
# [323]	validation_0-rmse:3.51749
# [324]	validation_0-rmse:3.51723
# [325]	validation_0-rmse:3.51679
# [326]	validation_0-rmse:3.51682
# [327]	validation_0-rmse:3.51658
# [328]	validation_0-rmse:3.51635
# [329]	validation_0-rmse:3.51598
# [330]	validation_0-rmse:3.51548
# [331]	validation_0-rmse:3.51405
# [332]	validation_0-rmse:3.51381
# [333]	validation_0-rmse:3.51363
# [334]	validation_0-rmse:3.51348
# [335]	validation_0-rmse:3.51318
# [336]	validation_0-rmse:3.51307
# [337]	validation_0-rmse:3.51311
# [338]	validation_0-rmse:3.51299
# [339]	validation_0-rmse:3.51276
# [340]	validation_0-rmse:3.51213
# [341]	validation_0-rmse:3.51193
# [342]	validation_0-rmse:3.51188
# [343]	validation_0-rmse:3.51195
# [344]	validation_0-rmse:3.51167
# [345]	validation_0-rmse:3.51136
# [346]	validation_0-rmse:3.51112
# [347]	validation_0-rmse:3.51100
# [348]	validation_0-rmse:3.51057
# [349]	validation_0-rmse:3.51030
# [350]	validation_0-rmse:3.51024
# [351]	validation_0-rmse:3.50981
# [352]	validation_0-rmse:3.50985
# [353]	validation_0-rmse:3.50983
# [354]	validation_0-rmse:3.50922
# [355]	validation_0-rmse:3.50820
# [356]	validation_0-rmse:3.50810
# [357]	validation_0-rmse:3.50790
# [358]	validation_0-rmse:3.50793
# [359]	validation_0-rmse:3.50761
# [360]	validation_0-rmse:3.50745
# [361]	validation_0-rmse:3.50743
# [362]	validation_0-rmse:3.50722
# [363]	validation_0-rmse:3.50706
# [364]	validation_0-rmse:3.50662
# [365]	validation_0-rmse:3.50669
# [366]	validation_0-rmse:3.50657
# [367]	validation_0-rmse:3.50615
# [368]	validation_0-rmse:3.50601
# [369]	validation_0-rmse:3.50584
# [370]	validation_0-rmse:3.50570
# [371]	validation_0-rmse:3.50533
# [372]	validation_0-rmse:3.50509
# [373]	validation_0-rmse:3.50495
# [374]	validation_0-rmse:3.50492
# [375]	validation_0-rmse:3.50464
# [376]	validation_0-rmse:3.50453
# [377]	validation_0-rmse:3.50418
# [378]	validation_0-rmse:3.50380
# [379]	validation_0-rmse:3.50337
# [380]	validation_0-rmse:3.50365
# [381]	validation_0-rmse:3.50342
# [382]	validation_0-rmse:3.50309
# [383]	validation_0-rmse:3.50307
# [384]	validation_0-rmse:3.50256
# [385]	validation_0-rmse:3.50255
# [386]	validation_0-rmse:3.50258
# [387]	validation_0-rmse:3.50303
# [388]	validation_0-rmse:3.50302
# [389]	validation_0-rmse:3.50270
# [390]	validation_0-rmse:3.50251
# [391]	validation_0-rmse:3.50236
# [392]	validation_0-rmse:3.50270
# [393]	validation_0-rmse:3.50269
# [394]	validation_0-rmse:3.50189
# [395]	validation_0-rmse:3.50181
# [396]	validation_0-rmse:3.50039
# [397]	validation_0-rmse:3.50016
# [398]	validation_0-rmse:3.49979
# [399]	validation_0-rmse:3.50035
# [400]	validation_0-rmse:3.49996
# [401]	validation_0-rmse:3.50008
# [402]	validation_0-rmse:3.50017
# [403]	validation_0-rmse:3.50013
# [404]	validation_0-rmse:3.49996
# [405]	validation_0-rmse:3.49971
# [406]	validation_0-rmse:3.49859
# [407]	validation_0-rmse:3.49858
# [408]	validation_0-rmse:3.49810
# [409]	validation_0-rmse:3.49866
# [410]	validation_0-rmse:3.49879
# [411]	validation_0-rmse:3.49907
# [412]	validation_0-rmse:3.49879
# [413]	validation_0-rmse:3.49836
# [414]	validation_0-rmse:3.49805
# [415]	validation_0-rmse:3.49767
# [416]	validation_0-rmse:3.49772
# [417]	validation_0-rmse:3.49762
# [418]	validation_0-rmse:3.49708
# [419]	validation_0-rmse:3.49670
# [420]	validation_0-rmse:3.49751
# [421]	validation_0-rmse:3.49722
# [422]	validation_0-rmse:3.49707
# [423]	validation_0-rmse:3.49740
# [424]	validation_0-rmse:3.49724
# [425]	validation_0-rmse:3.49685
# [426]	validation_0-rmse:3.49675
# [427]	validation_0-rmse:3.49667
# [428]	validation_0-rmse:3.49631
# [429]	validation_0-rmse:3.49641
# [430]	validation_0-rmse:3.49607
# [431]	validation_0-rmse:3.49589
# [432]	validation_0-rmse:3.49572
# [433]	validation_0-rmse:3.49551
# [434]	validation_0-rmse:3.49550
# [435]	validation_0-rmse:3.49532
# [436]	validation_0-rmse:3.49517
# [437]	validation_0-rmse:3.49510
# [438]	validation_0-rmse:3.49484
# [439]	validation_0-rmse:3.49472
# [440]	validation_0-rmse:3.49468
# [441]	validation_0-rmse:3.49458
# [442]	validation_0-rmse:3.49468
# [443]	validation_0-rmse:3.49457
# [444]	validation_0-rmse:3.49447
# [445]	validation_0-rmse:3.49433
# [446]	validation_0-rmse:3.49502
# [447]	validation_0-rmse:3.49499
# [448]	validation_0-rmse:3.49460
# [449]	validation_0-rmse:3.49426
# [450]	validation_0-rmse:3.49410
# [451]	validation_0-rmse:3.49401
# [452]	validation_0-rmse:3.49404
# [453]	validation_0-rmse:3.49384
# [454]	validation_0-rmse:3.49386
# [455]	validation_0-rmse:3.49395
# [456]	validation_0-rmse:3.49380
# [457]	validation_0-rmse:3.49337
# [458]	validation_0-rmse:3.49331
# [459]	validation_0-rmse:3.49280
# [460]	validation_0-rmse:3.49290
# [461]	validation_0-rmse:3.49342
# [462]	validation_0-rmse:3.49326
# [463]	validation_0-rmse:3.49316
# [464]	validation_0-rmse:3.49365
# [465]	validation_0-rmse:3.49332
# [466]	validation_0-rmse:3.49309
# [467]	validation_0-rmse:3.49268
# [468]	validation_0-rmse:3.49262
# [469]	validation_0-rmse:3.49311
# [470]	validation_0-rmse:3.49315
# [471]	validation_0-rmse:3.49315
# [472]	validation_0-rmse:3.49340
# [473]	validation_0-rmse:3.49346
# [474]	validation_0-rmse:3.49301
# [475]	validation_0-rmse:3.49312
# [476]	validation_0-rmse:3.49315
# [477]	validation_0-rmse:3.49297
# [478]	validation_0-rmse:3.49287
# [479]	validation_0-rmse:3.49272
# [480]	validation_0-rmse:3.49255
# [481]	validation_0-rmse:3.49207
# [482]	validation_0-rmse:3.49198
# [483]	validation_0-rmse:3.49185
# [484]	validation_0-rmse:3.49078
# [485]	validation_0-rmse:3.49054
# [486]	validation_0-rmse:3.49058
# [487]	validation_0-rmse:3.49035
# [488]	validation_0-rmse:3.49018
# [489]	validation_0-rmse:3.48974
# [490]	validation_0-rmse:3.48954
# [491]	validation_0-rmse:3.48942
# [492]	validation_0-rmse:3.48935
# [493]	validation_0-rmse:3.48921
# [494]	validation_0-rmse:3.48948
# [495]	validation_0-rmse:3.48915
# [496]	validation_0-rmse:3.48906
# [497]	validation_0-rmse:3.48890
# [498]	validation_0-rmse:3.48868
# [499]	validation_0-rmse:3.48803
# [500]	validation_0-rmse:3.48788
# [501]	validation_0-rmse:3.48791
# [502]	validation_0-rmse:3.48759
# [503]	validation_0-rmse:3.48704
# [504]	validation_0-rmse:3.48682
# [505]	validation_0-rmse:3.48674
# [506]	validation_0-rmse:3.48689
# [507]	validation_0-rmse:3.48672
# [508]	validation_0-rmse:3.48664
# [509]	validation_0-rmse:3.48658
# [510]	validation_0-rmse:3.48588
# [511]	validation_0-rmse:3.48585
# [512]	validation_0-rmse:3.48601
# [513]	validation_0-rmse:3.48583
# [514]	validation_0-rmse:3.48575
# [515]	validation_0-rmse:3.48569
# [516]	validation_0-rmse:3.48553
# [517]	validation_0-rmse:3.48587
# [518]	validation_0-rmse:3.48584
# [519]	validation_0-rmse:3.48574
# [520]	validation_0-rmse:3.48547
# [521]	validation_0-rmse:3.48544
# [522]	validation_0-rmse:3.48532
# [523]	validation_0-rmse:3.48571
# [524]	validation_0-rmse:3.48562
# [525]	validation_0-rmse:3.48553
# [526]	validation_0-rmse:3.48532
# [527]	validation_0-rmse:3.48517
# [528]	validation_0-rmse:3.48521
# [529]	validation_0-rmse:3.48519
# [530]	validation_0-rmse:3.48501
# [531]	validation_0-rmse:3.48585
# [532]	validation_0-rmse:3.48586
# [533]	validation_0-rmse:3.48573
# [534]	validation_0-rmse:3.48557
# [535]	validation_0-rmse:3.48561
# [536]	validation_0-rmse:3.48517
# [537]	validation_0-rmse:3.48530
# [538]	validation_0-rmse:3.48523
# [539]	validation_0-rmse:3.48509
# [540]	validation_0-rmse:3.48481
# [541]	validation_0-rmse:3.48426
# [542]	validation_0-rmse:3.48415
# [543]	validation_0-rmse:3.48391
# [544]	validation_0-rmse:3.48405
# [545]	validation_0-rmse:3.48389
# [546]	validation_0-rmse:3.48369
# [547]	validation_0-rmse:3.48344
# [548]	validation_0-rmse:3.48325
# [549]	validation_0-rmse:3.48303
# [550]	validation_0-rmse:3.48257
# [551]	validation_0-rmse:3.48238
# [552]	validation_0-rmse:3.48233
# [553]	validation_0-rmse:3.48233
# [554]	validation_0-rmse:3.48261
# [555]	validation_0-rmse:3.48302
# [556]	validation_0-rmse:3.48297
# [557]	validation_0-rmse:3.48265
# [558]	validation_0-rmse:3.48262
# [559]	validation_0-rmse:3.48256
# [560]	validation_0-rmse:3.48228
# [561]	validation_0-rmse:3.48208
# [562]	validation_0-rmse:3.48206
# [563]	validation_0-rmse:3.48204
# [564]	validation_0-rmse:3.48161
# [565]	validation_0-rmse:3.48154
# [566]	validation_0-rmse:3.48167
# [567]	validation_0-rmse:3.48148
# [568]	validation_0-rmse:3.48161
# [569]	validation_0-rmse:3.48185
# [570]	validation_0-rmse:3.48175
# [571]	validation_0-rmse:3.48178
# [572]	validation_0-rmse:3.48163
# [573]	validation_0-rmse:3.48150
# [574]	validation_0-rmse:3.48149
# [575]	validation_0-rmse:3.48223
# [576]	validation_0-rmse:3.48205
# [577]	validation_0-rmse:3.48173
# [578]	validation_0-rmse:3.48138
# [579]	validation_0-rmse:3.48173
# [580]	validation_0-rmse:3.48160
# [581]	validation_0-rmse:3.48160
# [582]	validation_0-rmse:3.48147
# [583]	validation_0-rmse:3.48150
# [584]	validation_0-rmse:3.48152
# [585]	validation_0-rmse:3.48151
# [586]	validation_0-rmse:3.48190
# [587]	validation_0-rmse:3.48200
# [588]	validation_0-rmse:3.48204
# [589]	validation_0-rmse:3.48196
# [590]	validation_0-rmse:3.48232
# [591]	validation_0-rmse:3.48236
# [592]	validation_0-rmse:3.48263
# [593]	validation_0-rmse:3.48250
# [594]	validation_0-rmse:3.48228
# [595]	validation_0-rmse:3.48236
# [596]	validation_0-rmse:3.48236
# [597]	validation_0-rmse:3.48226
# [598]	validation_0-rmse:3.48209
# [599]	validation_0-rmse:3.48191
# [600]	validation_0-rmse:3.48189
# [601]	validation_0-rmse:3.48206
# [602]	validation_0-rmse:3.48209
# [603]	validation_0-rmse:3.48180
# [604]	validation_0-rmse:3.48192
# [605]	validation_0-rmse:3.48161
# [606]	validation_0-rmse:3.48166
# [607]	validation_0-rmse:3.48146
# [608]	validation_0-rmse:3.48140
# [609]	validation_0-rmse:3.48119
# [610]	validation_0-rmse:3.48106
# [611]	validation_0-rmse:3.48072
# [612]	validation_0-rmse:3.48081
# [613]	validation_0-rmse:3.48070
# [614]	validation_0-rmse:3.48049
# [615]	validation_0-rmse:3.48044
# [616]	validation_0-rmse:3.48031
# [617]	validation_0-rmse:3.48020
# [618]	validation_0-rmse:3.48017
# [619]	validation_0-rmse:3.48018
# [620]	validation_0-rmse:3.48007
# [621]	validation_0-rmse:3.47980
# [622]	validation_0-rmse:3.47947
# [623]	validation_0-rmse:3.47938
# [624]	validation_0-rmse:3.47939
# [625]	validation_0-rmse:3.47905
# [626]	validation_0-rmse:3.47893
# [627]	validation_0-rmse:3.47905
# [628]	validation_0-rmse:3.47886
# [629]	validation_0-rmse:3.47866
# [630]	validation_0-rmse:3.47845
# [631]	validation_0-rmse:3.47837
# [632]	validation_0-rmse:3.47808
# [633]	validation_0-rmse:3.47795
# [634]	validation_0-rmse:3.47797
# [635]	validation_0-rmse:3.47774
# [636]	validation_0-rmse:3.47783
# [637]	validation_0-rmse:3.47790
# [638]	validation_0-rmse:3.47776
# [639]	validation_0-rmse:3.47751
# [640]	validation_0-rmse:3.47743
# [641]	validation_0-rmse:3.47736
# [642]	validation_0-rmse:3.47750
# [643]	validation_0-rmse:3.47757
# [644]	validation_0-rmse:3.47736
# [645]	validation_0-rmse:3.47708
# [646]	validation_0-rmse:3.47686
# [647]	validation_0-rmse:3.47677
# [648]	validation_0-rmse:3.47663
# [649]	validation_0-rmse:3.47681
# [650]	validation_0-rmse:3.47678
# [651]	validation_0-rmse:3.47645
# [652]	validation_0-rmse:3.47628
# [653]	validation_0-rmse:3.47643
# [654]	validation_0-rmse:3.47620
# [655]	validation_0-rmse:3.47608
# [656]	validation_0-rmse:3.47631
# [657]	validation_0-rmse:3.47605
# [658]	validation_0-rmse:3.47606
# [659]	validation_0-rmse:3.47612
# [660]	validation_0-rmse:3.47597
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8416317594127292, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.6099966577826209, gpu_id=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.09331949117361643, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=661, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred = my_model.predict(X_test)
# Calculate the RMSE
rmse = mean_squared_error(y_test, y_pred, squared=False)
print("Root Mean Squared Error (RMSE):", rmse, end='\n\n')
# Out:
# Root Mean Squared Error (RMSE): 3.6495172908672284

# %%
# Save the model to a file
file_name = "Data/xgb_model.pkl"
pickle.dump(my_model, open(file_name, "wb"))
